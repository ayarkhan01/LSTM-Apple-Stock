# %%
import yfinance as yf
import pandas as pd

# %%
# Define the stock symbols
symbols = ['AAPL']

# %%
# Define the start and end dates for historical data
start_date = '2010-01-01'
end_date = '2023-06-09'

# %%
# Create an empty DataFrame to store the stock data
stock_data = pd.DataFrame()

# %%
# Fetch historical data for each stock
for symbol in symbols:
    stock = yf.Ticker(symbol)
    data = stock.history(start=start_date, end=end_date)
    stock_data = pd.concat([stock_data, pd.DataFrame(data)], ignore_index=False)

# %%
stock_data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2010-01-04 00:00:00-05:00    6.453206    6.485558    6.421458    6.470742
# 2010-01-05 00:00:00-05:00    6.488580    6.518514    6.447762    6.481928
# 2010-01-06 00:00:00-05:00    6.481928    6.507628    6.372172    6.378824
# 2010-01-07 00:00:00-05:00    6.402409    6.409968    6.320772    6.367033
# 2010-01-08 00:00:00-05:00    6.358566    6.409967    6.321075    6.409362
# ...                               ...         ...         ...         ...
# 2023-06-02 00:00:00-04:00  180.317907  181.064957  178.554865  180.238220
# 2023-06-05 00:00:00-04:00  181.911617  184.222483  177.339661  178.873611
# 2023-06-06 00:00:00-04:00  179.262086  179.411490  176.732069  178.505081
# 2023-06-07 00:00:00-04:00  177.738101  180.497209  176.622511  177.120544
# 2023-06-08 00:00:00-04:00  177.200215  180.128653  176.761959  179.859726
#
#                               Volume  Dividends  Stock Splits
# Date
# 2010-01-04 00:00:00-05:00  493729600        0.0           0.0
# 2010-01-05 00:00:00-05:00  601904800        0.0           0.0
# 2010-01-06 00:00:00-05:00  552160000        0.0           0.0
# 2010-01-07 00:00:00-05:00  477131200        0.0           0.0
# 2010-01-08 00:00:00-05:00  447610800        0.0           0.0
# ...                              ...        ...           ...
# 2023-06-02 00:00:00-04:00   61945900        0.0           0.0
# 2023-06-05 00:00:00-04:00  121946500        0.0           0.0
# 2023-06-06 00:00:00-04:00   64848400        0.0           0.0
# 2023-06-07 00:00:00-04:00   61944600        0.0           0.0
# 2023-06-08 00:00:00-04:00   50214900        0.0           0.0
#
# [3381 rows x 7 columns]

# %%
# Reset the index and rename columns
stock_data.reset_index(inplace=True)
stock_data.rename(columns={'Date': 'Date', 'Open': 'Open', 'High': 'High', 'Low': 'Low', 'Close': 'Close', 'Volume': 'Volume'}, inplace=True)

# %%
stock_data
# Out:
#                           Date        Open        High         Low  \
# 0    2010-01-04 00:00:00-05:00    6.453206    6.485558    6.421458
# 1    2010-01-05 00:00:00-05:00    6.488580    6.518514    6.447762
# 2    2010-01-06 00:00:00-05:00    6.481928    6.507628    6.372172
# 3    2010-01-07 00:00:00-05:00    6.402409    6.409968    6.320772
# 4    2010-01-08 00:00:00-05:00    6.358566    6.409967    6.321075
# ...                        ...         ...         ...         ...
# 3376 2023-06-02 00:00:00-04:00  180.317907  181.064957  178.554865
# 3377 2023-06-05 00:00:00-04:00  181.911617  184.222483  177.339661
# 3378 2023-06-06 00:00:00-04:00  179.262086  179.411490  176.732069
# 3379 2023-06-07 00:00:00-04:00  177.738101  180.497209  176.622511
# 3380 2023-06-08 00:00:00-04:00  177.200215  180.128653  176.761959
#
#            Close     Volume  Dividends  Stock Splits
# 0       6.470742  493729600        0.0           0.0
# 1       6.481928  601904800        0.0           0.0
# 2       6.378824  552160000        0.0           0.0
# 3       6.367033  477131200        0.0           0.0
# 4       6.409362  447610800        0.0           0.0
# ...          ...        ...        ...           ...
# 3376  180.238220   61945900        0.0           0.0
# 3377  178.873611  121946500        0.0           0.0
# 3378  178.505081   64848400        0.0           0.0
# 3379  177.120544   61944600        0.0           0.0
# 3380  179.859726   50214900        0.0           0.0
#
# [3381 rows x 8 columns]

# %%
# Save the stock data to a CSV file
stock_data.to_csv('stock_data.csv', index=False)
